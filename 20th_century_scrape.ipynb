# %% [markdown]
# # Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import os

url = "https://en.wikipedia.org/wiki/Key_events_of_the_20th_century"

headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers, timeout=30)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Get full page text
page_text = soup.get_text(separator="\n", strip=True)

# Save to .txt in working directory
output_file = "key_events_20th_century.txt"
with open(output_file, "w", encoding="utf-8") as f:
    f.write(page_text)

print(f"Saved file: {os.path.abspath(output_file)}")
# Out:
# Saved file: /Users/mariatirado/20th-century/key_events_20th_century.txt
